# %% [markdown]
# # Package installation

# %%
import sys
import os

if 'google.colab' in sys.modules:
    # !pip install idaes-pse --pre
    # !idaes get-extensions --to ./bin
    os.environ['PATH'] += ':bin'

import pyomo.environ as pyomo
import numpy as np
# Out:
# Collecting idaes-pse
#   Downloading idaes_pse-2.5.0rc0-py3-none-any.whl (17.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 31.9 MB/s eta 0:00:00
# Collecting pyomo>=6.7.3 (from idaes-pse)
#   Downloading Pyomo-6.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 55.6 MB/s eta 0:00:00
# Collecting pint (from idaes-pse)
#   Downloading Pint-0.24rc2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (3.3)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.25.2)
# Requirement already satisfied: pandas!=2.1.0,<3 in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.11.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.12.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (3.7.1)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,<3->idaes-pse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,<3->idaes-pse) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,<3->idaes-pse) (2024.1)
# Collecting ply (from pyomo>=6.7.3->idaes-pse)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (3.1.2)
# Collecting appdirs>=1.4.4 (from pint->idaes-pse)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pint->idaes-pse) (4.12.0)
# Collecting flexcache>=0.3 (from pint->idaes-pse)
#   Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Collecting flexparser>=0.3 (from pint->idaes-pse)
#   Downloading flexparser-0.3-py3-none-any.whl (26 kB)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->idaes-pse) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,<3->idaes-pse) (1.16.0)
# Installing collected packages: ply, appdirs, pyomo, flexparser, flexcache, pint, idaes-pse
# Successfully installed appdirs-1.4.4 flexcache-0.3 flexparser-0.3 idaes-pse-2.5.0rc0 pint-0.24rc2 ply-3.11 pyomo-6.7.3
# Getting files...
# Done
# ---------------------------------------------------
# IDAES Extensions Build Versions
# ===================================================
# Solvers:  vno version file found
# Library:  vno version file found
# ===================================================

# %% [markdown]
# # Example 1 - Regression

# %%
# Model definition
model_linear = pyomo.ConcreteModel();
model_nonlinear = pyomo.ConcreteModel();

# Set declaration
model_linear.m = pyomo.RangeSet(6);
model_nonlinear.m = pyomo.RangeSet(6);

# Variable definition
model_linear.a1 = pyomo.Var(domain=pyomo.Reals);
model_linear.a2 = pyomo.Var(domain=pyomo.Reals);

model_nonlinear.b1 = pyomo.Var(domain=pyomo.Reals, initialize = 500);
model_nonlinear.b2 = pyomo.Var(domain=pyomo.Reals, initialize = -150);
model_nonlinear.b3 = pyomo.Var(domain=pyomo.Reals, initialize = -0.2,bounds = (-5,5));

# Parameter declaration
model_linear.datapoints_y = pyomo.Param(model_linear.m,initialize = {1:127,2:151,3:379,4:421,5:460,6:426});
model_linear.datapoints_x = pyomo.Param(model_linear.m,initialize = {1:-5,2:-3,3:-1,4:5,5:3,6:1});

model_nonlinear.datapoints_y = pyomo.Param(model_nonlinear.m,initialize = {1:127,2:151,3:379,4:421,5:460,6:426});
model_nonlinear.datapoints_x = pyomo.Param(model_nonlinear.m,initialize = {1:-5,2:-3,3:-1,4:5,5:3,6:1});

# Objective functions
model_linear.obj = pyomo.Objective(expr = sum((model_linear.datapoints_y[m] -
                                               (model_linear.a1 + model_linear.a2*model_linear.datapoints_x[m]))**2
                                              for m in model_linear.m),sense = pyomo.minimize);
model_nonlinear.obj = pyomo.Objective(expr = sum((model_nonlinear.datapoints_y[m] -
                                               (model_nonlinear.b1 + model_nonlinear.b2*pyomo.exp(model_nonlinear.b3*model_nonlinear.datapoints_x[m])))**2
                                              for m in model_nonlinear.m),sense = pyomo.minimize);

# Solver options

results = pyomo.SolverFactory('ipopt').solve(model_linear);

results.write()
print("\n RESULTS \n");
print("Squared deviation for linear regression model = ",model_linear.obj());
print("Coefficient 1 for linear regression (a1) = ",model_linear.a1());
print("Coefficient 2 for linear regression (a2) = ",model_linear.a2());

results = pyomo.SolverFactory('ipopt').solve(model_nonlinear);

results.write()
print("\n RESULTS \n");
print("Squared deviation for nonlinear regression model = ",model_nonlinear.obj());
print("Coefficient 1 for nonlinear regression (b1) = ",model_nonlinear.b1());
print("Coefficient 2 for nonlinear regression (b2) = ",model_nonlinear.b2());
print("Coefficient 3 for nonlinear regression (b3) = ",model_nonlinear.b3());
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 2
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.09103035926818848
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#  RESULTS
#
# Squared deviation for linear regression model =  24674.819047619047
# Coefficient 1 for linear regression (a1) =  327.3333333333333
# Coefficient 2 for linear regression (a2) =  34.914285714285704
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 3
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.016840219497680664
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#  RESULTS
#
# Squared deviation for nonlinear regression model =  14085.139848928411
# Coefficient 1 for nonlinear regression (b1) =  516.6511741716854
# Coefficient 2 for nonlinear regression (b2) =  -149.35189369630746
# Coefficient 3 for nonlinear regression (b3) =  -0.20664276797258013

# %% [markdown]
# # Example 2 - Geometric example

# %%
model_circle = pyomo.ConcreteModel();

# Set definition
model_circle.i = pyomo.RangeSet(5);
model_circle.j = pyomo.Set(initialize = model_circle.i); # Creates an alias of set i

# Variable declaration
model_circle.r = pyomo.Var(domain = pyomo.NonNegativeReals, bounds = (0.05,0.4));

# Function to initialuze coordinate variables
def init(model_circle,l):
  return -0.2 + l*0.1

model_circle.x = pyomo.Var(model_circle.i,domain = pyomo.Reals, bounds = (-1,1), initialize = init);
model_circle.y = pyomo.Var(model_circle.i,domain = pyomo.Reals, bounds = (-1,1), initialize = init);

# Constraint definition
def rule4(model_circle,i):
  return (1-model_circle.r)**2 >= (model_circle.x[i])**2 + (model_circle.y[i])**2
model_circle.eq4 = pyomo.Constraint(model_circle.i,rule = rule4, doc = 'Containment constraint');

def rule5(model_circle,i,j):
  if i < j:
    return (model_circle.x[i] - model_circle.x[j])**2 + (model_circle.y[i] - model_circle.y[j])**2 >= 4*(model_circle.r**2)
  return pyomo.Constraint.Skip
model_circle.eq5 = pyomo.Constraint(model_circle.i,model_circle.j, rule = rule5, doc = 'No overlap constraint');

# Objective function
model_circle.obj = pyomo.Objective(expr = model_circle.r, sense = pyomo.maximize);

# Solve statement
results = pyomo.SolverFactory('ipopt').solve(model_circle);

# Printing results
results.write()
print("\n RESULTS \n");
print("Radius of identically sized circles = ",model_circle.r(),"\n");
for i in model_circle.i:
  print("Coordinates of circle ", i, "=> (",model_circle.x[i](),",",model_circle.y[i](),") \n")
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 15
#   Number of variables: 11
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.04493570327758789
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#  RESULTS
#
# Radius of identically sized circles =  0.37019188928790975
#
# Coordinates of circle  1 => ( -0.2838983654315452 , -0.5621920865323791 )
#
# Coordinates of circle  2 => ( -0.6224058669315771 , 0.09627648161700385 )
#
# Coordinates of circle  3 => ( 0.446947027607146 , -0.4437302993161179 )
#
# Coordinates of circle  4 => ( -0.1007696149205879 , 0.6216942245300807 )
#
# Coordinates of circle  5 => ( 0.5601268198358612 , 0.28795167954324485 )

# %% [markdown]
# # Example 3 - resource allocation

# %%
model = pyomo.ConcreteModel();

# Set declaration
model.w = pyomo.Set(initialize = ['ICBM','MRBM-1','LR-Bomber','F-Bomber','MRBM-2']);
model.t = pyomo.RangeSet(20);

model.t_spec = pyomo.Set(within = model.t,initialize = [1,6,10,14,15,16,20]);

# Variable declaration
model.x = pyomo.Var(model.w,model.t,domain = pyomo.NonNegativeReals);

# Parameter declaration
model.phi = pyomo.Param(model.w,model.t,initialize = {('ICBM',1):1.00,('ICBM',2):0.95,('ICBM',3):1.00,('ICBM',4):1.00,('ICBM',5):1.00,
                                                      ('ICBM',6):0.85,('ICBM',7):0.90,('ICBM',8):0.85,('ICBM',9):0.80,('ICBM',10):1.00,
                                                      ('ICBM',11):1.00,('ICBM',12):1.00,('ICBM',13):1.00,('ICBM',14):1.00,('ICBM',15):1.00,
                                                      ('ICBM',16):1.00,('ICBM',17):1.00,('ICBM',18):0.95,('ICBM',19):1.00,('ICBM',20):1.00,

                                                      ('MRBM-1',1):0.84,('MRBM-1',2):0.83,('MRBM-1',3):0.85,('MRBM-1',4):0.84,('MRBM-1',5):0.85,
                                                      ('MRBM-1',6):0.81,('MRBM-1',7):0.81,('MRBM-1',8):0.82,('MRBM-1',9):0.80,('MRBM-1',10):0.86,
                                                      ('MRBM-1',11):1.00,('MRBM-1',12):0.98,('MRBM-1',13):1.00,('MRBM-1',14):0.88,('MRBM-1',15):0.87,
                                                      ('MRBM-1',16):0.88,('MRBM-1',17):0.85,('MRBM-1',18):0.84,('MRBM-1',19):0.85,('MRBM-1',20):0.85,

                                                      ('LR-Bomber',1):0.96,('LR-Bomber',2):0.95,('LR-Bomber',3):0.96,('LR-Bomber',4):0.96,('LR-Bomber',5):0.96,
                                                      ('LR-Bomber',6):0.90,('LR-Bomber',7):0.92,('LR-Bomber',8):0.91,('LR-Bomber',9):0.92,('LR-Bomber',10):0.95,
                                                      ('LR-Bomber',11):0.99,('LR-Bomber',12):0.98,('LR-Bomber',13):0.99,('LR-Bomber',14):0.98,('LR-Bomber',15):0.97,
                                                      ('LR-Bomber',16):0.98,('LR-Bomber',17):0.95,('LR-Bomber',18):0.92,('LR-Bomber',19):0.93,('LR-Bomber',20):0.92,

                                                      ('F-Bomber',1):1.00,('F-Bomber',2):1.00,('F-Bomber',3):1.00,('F-Bomber',4):1.00,('F-Bomber',5):1.00,
                                                      ('F-Bomber',6):1.00,('F-Bomber',7):1.00,('F-Bomber',8):1.00,('F-Bomber',9):1.00,('F-Bomber',10):0.96,
                                                      ('F-Bomber',11):0.91,('F-Bomber',12):0.92,('F-Bomber',13):0.91,('F-Bomber',14):0.92,('F-Bomber',15):0.98,
                                                      ('F-Bomber',16):0.93,('F-Bomber',17):1.00,('F-Bomber',18):1.00,('F-Bomber',19):1.00,('F-Bomber',20):1.00,

                                                      ('MRBM-2',1):0.92,('MRBM-2',2):0.94,('MRBM-2',3):0.92,('MRBM-2',4):0.95,('MRBM-2',5):0.95,
                                                      ('MRBM-2',6):0.98,('MRBM-2',7):0.98,('MRBM-2',8):1.00,('MRBM-2',9):1.00,('MRBM-2',10):0.90,
                                                      ('MRBM-2',11):0.95,('MRBM-2',12):0.96,('MRBM-2',13):0.91,('MRBM-2',14):0.98,('MRBM-2',15):0.99,
                                                      ('MRBM-2',16):0.99,('MRBM-2',17):1.00,('MRBM-2',18):1.00,('MRBM-2',19):1.00,('MRBM-2',20):1.00
                                                      });

# Total number of weapons available per type w
model.alpha = pyomo.Param(model.w,initialize = {'ICBM':200,'MRBM-1':100,'LR-Bomber':300,'F-Bomber':150,'MRBM-2':250});

# Military value of targets per type t
model.beta = pyomo.Param(model.t,initialize = {1:60,2:50,3:50,4:75,5:40,6:60,7:35,8:30,9:25,10:150,
                                               11:30,12:45,13:125,14:200,15:200,16:130,17:100,18:100,19:100,20:150});

# Minimum number of weapons to be assigned to specified targets
model.gamma = pyomo.Param(model.t_spec,initialize = {1:30,6:100,10:40,14:50,15:70,16:35,20:10});

# Constraint declaration
def rule1(model,w):
  return sum(model.x[w,t] for t in model.t) <= model.alpha[w]
model.eq1 = pyomo.Constraint(model.w,rule = rule1, doc = 'upper limit on number of weapons assigned based on availability');

def rule2(model,t_spec):
  return sum(model.x[w,t_spec] for w in model.w) >= model.gamma[t_spec]
model.eq2 = pyomo.Constraint(model.t_spec,rule = rule2, doc = 'lower limit on weapons assigned');

# Objective function
# Product function
from functools import reduce
import operator
def prod(iterable):
  return reduce(operator.mul,iterable,1)

model.obj = pyomo.Objective(expr = sum(model.beta[t]*(1-prod(model.phi[w,t]**model.x[w,t] for w in model.w))
                            for t in model.t),sense = pyomo.maximize)

# Solve statement
results = pyomo.SolverFactory('ipopt').solve(model);

results.write()
print("\n RESULTS \n");
print("Total damage = ",model.obj(),"\n");
for w in model.w:
  for t in model.t:
    print("Number of weapons of type ",w," assigned to target ",t,"=>",model.x[w,t]()," \n");
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 12
#   Number of variables: 100
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.034427642822265625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#  RESULTS
#
# Total damage =  1735.5695806926828
#
# Number of weapons of type  ICBM  assigned to target  1 => 3.195773385899619e-08
#
# Number of weapons of type  ICBM  assigned to target  2 => 13.516460293073278
#
# Number of weapons of type  ICBM  assigned to target  3 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  4 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  5 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  6 => 99.999998533101
#
# Number of weapons of type  ICBM  assigned to target  7 => 39.100041980172385
#
# Number of weapons of type  ICBM  assigned to target  8 => 27.06673282649615
#
# Number of weapons of type  ICBM  assigned to target  9 => 20.316767710828692
#
# Number of weapons of type  ICBM  assigned to target  10 => 3.191824151643351e-08
#
# Number of weapons of type  ICBM  assigned to target  11 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  12 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  13 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  14 => 3.189602816018415e-08
#
# Number of weapons of type  ICBM  assigned to target  15 => 6.659242329403782e-08
#
# Number of weapons of type  ICBM  assigned to target  16 => 3.1852679306319765e-08
#
# Number of weapons of type  ICBM  assigned to target  17 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  18 => 1.3209803773158357e-07
#
# Number of weapons of type  ICBM  assigned to target  19 => 3.2003127030375326e-08
#
# Number of weapons of type  ICBM  assigned to target  20 => 3.198510553392334e-08
#
# Number of weapons of type  MRBM-1  assigned to target  1 => 2.8378062270475253e-08
#
# Number of weapons of type  MRBM-1  assigned to target  2 => 1.360458081810115
#
# Number of weapons of type  MRBM-1  assigned to target  3 => 2.315095770926719e-08
#
# Number of weapons of type  MRBM-1  assigned to target  4 => 23.489534312141128
#
# Number of weapons of type  MRBM-1  assigned to target  5 => 20.89960526599499
#
# Number of weapons of type  MRBM-1  assigned to target  6 => 6.021079150745124e-09
#
# Number of weapons of type  MRBM-1  assigned to target  7 => 1.591413067714899e-08
#
# Number of weapons of type  MRBM-1  assigned to target  8 => 7.502234240430923e-09
#
# Number of weapons of type  MRBM-1  assigned to target  9 => 6.02640295887124e-09
#
# Number of weapons of type  MRBM-1  assigned to target  10 => 1.2205725272330389e-08
#
# Number of weapons of type  MRBM-1  assigned to target  11 => 1.5968026774613526e-09
#
# Number of weapons of type  MRBM-1  assigned to target  12 => 3.444468761124104e-09
#
# Number of weapons of type  MRBM-1  assigned to target  13 => 1.5968026774613526e-09
#
# Number of weapons of type  MRBM-1  assigned to target  14 => 7.913162604018321e-08
#
# Number of weapons of type  MRBM-1  assigned to target  15 => 26.211182869929868
#
# Number of weapons of type  MRBM-1  assigned to target  16 => 24.23646653785186
#
# Number of weapons of type  MRBM-1  assigned to target  17 => 3.80275366155635
#
# Number of weapons of type  MRBM-1  assigned to target  18 => 2.4216121941271344e-08
#
# Number of weapons of type  MRBM-1  assigned to target  19 => 2.97111546255977e-08
#
# Number of weapons of type  MRBM-1  assigned to target  20 => 2.022333704622395e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  1 => 6.585819563598172e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  2 => 2.8353072245395055e-07
#
# Number of weapons of type  LR-Bomber  assigned to target  3 => 6.593451313861929e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  4 => 1.3168785077071583e-07
#
# Number of weapons of type  LR-Bomber  assigned to target  5 => 1.6900221579002899e-07
#
# Number of weapons of type  LR-Bomber  assigned to target  6 => 2.8069492217613597e-07
#
# Number of weapons of type  LR-Bomber  assigned to target  7 => 1.090390868131269e-07
#
# Number of weapons of type  LR-Bomber  assigned to target  8 => 6.448586331081116e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  9 => 4.450625981624256e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  10 => 6.534124015195996e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  11 => 3.537209812938335e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  12 => 5.492686544113776e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  13 => 3.1344363306560824e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  14 => 5.472882504106621e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  15 => 43.788816360064466
#
# Number of weapons of type  LR-Bomber  assigned to target  16 => 6.302830470519415e-08
#
# Number of weapons of type  LR-Bomber  assigned to target  17 => 72.0338367579482
#
# Number of weapons of type  LR-Bomber  assigned to target  18 => 57.55153969671256
#
# Number of weapons of type  LR-Bomber  assigned to target  19 => 64.21150456949366
#
# Number of weapons of type  LR-Bomber  assigned to target  20 => 62.41430405960589
#
# Number of weapons of type  F-Bomber  assigned to target  1 => 1.0440236342334919e-08
#
# Number of weapons of type  F-Bomber  assigned to target  2 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  3 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  4 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  5 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  6 => 2.9863483159207584e-08
#
# Number of weapons of type  F-Bomber  assigned to target  7 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  8 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  9 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  10 => 1.64677769813662e-08
#
# Number of weapons of type  F-Bomber  assigned to target  11 => 33.19736272961265
#
# Number of weapons of type  F-Bomber  assigned to target  12 => 40.93425800909736
#
# Number of weapons of type  F-Bomber  assigned to target  13 => 3.966654069198863e-08
#
# Number of weapons of type  F-Bomber  assigned to target  14 => 58.823753006289145
#
# Number of weapons of type  F-Bomber  assigned to target  15 => 2.677309643725633e-08
#
# Number of weapons of type  F-Bomber  assigned to target  16 => 17.044627496383008
#
# Number of weapons of type  F-Bomber  assigned to target  17 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  18 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  19 => 1.0450911382207167e-08
#
# Number of weapons of type  F-Bomber  assigned to target  20 => 1.0446673348629595e-08
#
# Number of weapons of type  MRBM-2  assigned to target  1 => 50.815452596865875
#
# Number of weapons of type  MRBM-2  assigned to target  2 => 45.408192622762805
#
# Number of weapons of type  MRBM-2  assigned to target  3 => 48.62886061848321
#
# Number of weapons of type  MRBM-2  assigned to target  4 => 2.855057333279792e-07
#
# Number of weapons of type  MRBM-2  assigned to target  5 => 6.389764747262352e-07
#
# Number of weapons of type  MRBM-2  assigned to target  6 => 1.923137846633876e-07
#
# Number of weapons of type  MRBM-2  assigned to target  7 => 3.134322061736642e-08
#
# Number of weapons of type  MRBM-2  assigned to target  8 => 2.4775972814522804e-08
#
# Number of weapons of type  MRBM-2  assigned to target  9 => 2.4775972814522804e-08
#
# Number of weapons of type  MRBM-2  assigned to target  10 => 51.13229639110288
#
# Number of weapons of type  MRBM-2  assigned to target  11 => 4.523356298426185e-07
#
# Number of weapons of type  MRBM-2  assigned to target  12 => 1.9774083906371831e-07
#
# Number of weapons of type  MRBM-2  assigned to target  13 => 54.0151981351708
#
# Number of weapons of type  MRBM-2  assigned to target  14 => 4.898694783435462e-08
#
# Number of weapons of type  MRBM-2  assigned to target  15 => 6.964832706665621e-08
#
# Number of weapons of type  MRBM-2  assigned to target  16 => 3.5344007585162945e-08
#
# Number of weapons of type  MRBM-2  assigned to target  17 => 2.4775972814522804e-08
#
# Number of weapons of type  MRBM-2  assigned to target  18 => 2.4775972814522804e-08
#
# Number of weapons of type  MRBM-2  assigned to target  19 => 2.4775972814522804e-08
#
# Number of weapons of type  MRBM-2  assigned to target  20 => 2.476358835688019e-08
